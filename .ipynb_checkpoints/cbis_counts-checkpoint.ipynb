# %%
import sys, os, shutil, PIL
from pathlib import Path
import pandas as pd
from PIL import Image
import numpy as np

# %%
basedir = Path(os.path.abspath("../data/cbis-ddsm/"))

# %%
calc_test = pd.read_csv(basedir / "calc_case_description_test_set.csv")
mass_test = pd.read_csv(basedir / "mass_case_description_test_set.csv")
meta = pd.read_csv(basedir / "manifest-ZkhPvrLo5216730872708713142" / "metadata2.csv")

# %%
# Align their columns
calc_test = calc_test.rename(columns={
    "breast density":"breast_density",
    })

# Concat test cases
all_test = pd.concat([calc_test, mass_test])

# %%
all_test['patient_id'].nunique()
# Out:
# 349

# %%
def ambigious_labels(df, pathology_variable):
    # Remove cases with ambiguous labels, as those correspond to ROI-level labels (rather than whole image)
    counts = df.groupby(["patient_id"])[pathology_variable].nunique().reset_index(name='count') \
                                .sort_values(['count'], ascending=False)
    print(counts)
    #multi_label_list = list(counts[counts["count"] > 1]["image file path"])
    #df = df[~df["image file path"].isin(multi_label_list)]

# %%
ambigious_labels(calc_test, "pathology_fixed")
ambigious_labels(mass_test, "pathology_fixed")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1023/2123387296.py in <module>
# ----> 1 ambigious_labels(calc_test, "pathology_fixed")
#       2 ambigious_labels(mass_test, "pathology_fixed")
#
# /tmp/ipykernel_1023/431549242.py in ambigious_labels(df, pathology_variable)
#       1 def ambigious_labels(df, pathology_variable):
#       2     # Remove cases with ambiguous labels, as those correspond to ROI-level labels (rather than whole image)
# ----> 3     counts = df.groupby(["patient_id"])[pathology_variable].nunique().reset_index(name='count') \
#       4                                 .sort_values(['count'], ascending=False)
#       5     print(counts)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: pathology_fixed'

# %%
def clean_dupli(df):
    df = df.sort_values(by=['pathology'], ascending=False)
    df.drop_duplicates(subset=['image file path'], inplace=True)
    return df

# %%
calc_test2 = clean_dupli(calc_test)
mass_test2 = clean_dupli(mass_test)

# %%
def get_specs(df):
    print("Unique ROIs")
    print(df['ROI mask file path'].nunique())
    df["pathology_fixed"] = "BENIGN"
    df.loc[(df["pathology"] == "MALIGNANT"), "pathology_fixed"] = "MALIGNANT"
    pathology_counts = df.groupby("pathology_fixed").nunique()[["ROI mask file path"]]
    print(pathology_counts)

# %%
# Calc test set
get_specs(calc_test)
# Out:
# Unique ROIs
# 326
#                  ROI mask file path
# pathology_fixed
# BENIGN                          197
# MALIGNANT                       129

# %%
# Mass test set
get_specs(mass_test)
# Out:
# Unique ROIs
# 378
#                  ROI mask file path
# pathology_fixed
# BENIGN                          231
# MALIGNANT                       147

# %%
mass_test
# Out:
#     patient_id  breast_density left or right breast image view  \
# 0      P_00016               4                 LEFT         CC
# 1      P_00016               4                 LEFT        MLO
# 2      P_00017               2                 LEFT         CC
# 3      P_00017               2                 LEFT        MLO
# 4      P_00032               3                RIGHT         CC
# ..         ...             ...                  ...        ...
# 373    P_01825               2                RIGHT        MLO
# 374    P_01833               2                RIGHT        MLO
# 375    P_01865               2                 LEFT        MLO
# 376    P_01912               3                RIGHT         CC
# 377    P_01912               3                RIGHT        MLO
#
#      abnormality id abnormality type mass shape    mass margins  assessment  \
# 0                 1             mass  IRREGULAR      SPICULATED           5
# 1                 1             mass  IRREGULAR      SPICULATED           5
# 2                 1             mass      ROUND   CIRCUMSCRIBED           4
# 3                 1             mass      ROUND     ILL_DEFINED           4
# 4                 1             mass      ROUND        OBSCURED           0
# ..              ...              ...        ...             ...         ...
# 373               1             mass  LOBULATED  MICROLOBULATED           3
# 374               1             mass  IRREGULAR     ILL_DEFINED           5
# 375               1             mass  IRREGULAR     ILL_DEFINED           4
# 376               1             mass  IRREGULAR      SPICULATED           5
# 377               1             mass  IRREGULAR      SPICULATED           5
#
#                    pathology  subtlety  \
# 0                  MALIGNANT         5
# 1                  MALIGNANT         5
# 2                  MALIGNANT         4
# 3                  MALIGNANT         4
# 4                     BENIGN         2
# ..                       ...       ...
# 373  BENIGN_WITHOUT_CALLBACK         3
# 374                MALIGNANT         5
# 375                MALIGNANT         2
# 376                MALIGNANT         4
# 377                MALIGNANT         4
#
#                                        image file path  \
# 0    Mass-Test_P_00016_LEFT_CC/1.3.6.1.4.1.9590.100...
# 1    Mass-Test_P_00016_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 2    Mass-Test_P_00017_LEFT_CC/1.3.6.1.4.1.9590.100...
# 3    Mass-Test_P_00017_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 4    Mass-Test_P_00032_RIGHT_CC/1.3.6.1.4.1.9590.10...
# ..                                                 ...
# 373  Mass-Test_P_01825_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# 374  Mass-Test_P_01833_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# 375  Mass-Test_P_01865_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 376  Mass-Test_P_01912_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 377  Mass-Test_P_01912_RIGHT_MLO/1.3.6.1.4.1.9590.1...
#
#                                cropped image file path  \
# 0    Mass-Test_P_00016_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1    Mass-Test_P_00016_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2    Mass-Test_P_00017_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 3    Mass-Test_P_00017_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 4    Mass-Test_P_00032_RIGHT_CC_1/1.3.6.1.4.1.9590....
# ..                                                 ...
# 373  Mass-Test_P_01825_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 374  Mass-Test_P_01833_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# 375  Mass-Test_P_01865_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 376  Mass-Test_P_01912_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 377  Mass-Test_P_01912_RIGHT_MLO_1/1.3.6.1.4.1.9590...
#
#                                     ROI mask file path pathology_fixed
# 0    Mass-Test_P_00016_LEFT_CC_1/1.3.6.1.4.1.9590.1...       MALIGNANT
# 1    Mass-Test_P_00016_LEFT_MLO_1/1.3.6.1.4.1.9590....       MALIGNANT
# 2    Mass-Test_P_00017_LEFT_CC_1/1.3.6.1.4.1.9590.1...       MALIGNANT
# 3    Mass-Test_P_00017_LEFT_MLO_1/1.3.6.1.4.1.9590....       MALIGNANT
# 4    Mass-Test_P_00032_RIGHT_CC_1/1.3.6.1.4.1.9590....          BENIGN
# ..                                                 ...             ...
# 373  Mass-Test_P_01825_RIGHT_MLO_1/1.3.6.1.4.1.9590...          BENIGN
# 374  Mass-Test_P_01833_RIGHT_MLO_1/1.3.6.1.4.1.9590...       MALIGNANT
# 375  Mass-Test_P_01865_LEFT_MLO_1/1.3.6.1.4.1.9590....       MALIGNANT
# 376  Mass-Test_P_01912_RIGHT_CC_1/1.3.6.1.4.1.9590....       MALIGNANT
# 377  Mass-Test_P_01912_RIGHT_MLO_1/1.3.6.1.4.1.9590...       MALIGNANT
#
# [378 rows x 15 columns]

# %%
meta
# Out:
#                                              Series UID Collection  \
# 0     1.3.6.1.4.1.9590.100.1.2.419081637812053404913...  CBIS-DDSM
# 1     1.3.6.1.4.1.9590.100.1.2.188613955710170417803...  CBIS-DDSM
# 2     1.3.6.1.4.1.9590.100.1.2.374115997511889073021...  CBIS-DDSM
# 3     1.3.6.1.4.1.9590.100.1.2.174390361112646747718...  CBIS-DDSM
# 4     1.3.6.1.4.1.9590.100.1.2.244876997513875090239...  CBIS-DDSM
# ...                                                 ...        ...
# 6770  1.3.6.1.4.1.9590.100.1.2.321062807811123845106...  CBIS-DDSM
# 6771  1.3.6.1.4.1.9590.100.1.2.203989029910964209440...  CBIS-DDSM
# 6772  1.3.6.1.4.1.9590.100.1.2.290251769212905477734...  CBIS-DDSM
# 6773  1.3.6.1.4.1.9590.100.1.2.412558050811722685411...  CBIS-DDSM
# 6774  1.3.6.1.4.1.9590.100.1.2.364927700011315459741...  CBIS-DDSM
#
#       3rd Party Analysis                           Data Description URI  \
# 0                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 1                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 2                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 3                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 4                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# ...                  ...                                            ...
# 6770                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6771                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6772                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6773                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6774                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
#
#                             Subject ID  \
# 0          Calc-Test_P_00038_LEFT_CC_1
# 1         Calc-Test_P_00038_LEFT_MLO_1
# 2            Calc-Test_P_00038_LEFT_CC
# 3           Calc-Test_P_00038_LEFT_MLO
# 4         Calc-Test_P_00038_RIGHT_CC_1
# ...                                ...
# 6770  Mass-Training_P_02092_LEFT_MLO_1
# 6771  Mass-Training_P_02092_LEFT_MLO_1
# 6772    Mass-Training_P_02092_LEFT_MLO
# 6773   Mass-Training_P_02079_RIGHT_MLO
# 6774  Mass-Training_P_01761_LEFT_MLO_1
#
#                                               Study UID  Study Description  \
# 0     1.3.6.1.4.1.9590.100.1.2.161465562211359959230...                NaN
# 1     1.3.6.1.4.1.9590.100.1.2.291121996131431385353...                NaN
# 2     1.3.6.1.4.1.9590.100.1.2.859354343102033567126...                NaN
# 3     1.3.6.1.4.1.9590.100.1.2.384159464510350889125...                NaN
# 4     1.3.6.1.4.1.9590.100.1.2.200764632211227648028...                NaN
# ...                                                 ...                ...
# 6770  1.3.6.1.4.1.9590.100.1.2.195655760513031195523...                NaN
# 6771  1.3.6.1.4.1.9590.100.1.2.222512969612930058132...                NaN
# 6772  1.3.6.1.4.1.9590.100.1.2.322851018411213611731...                NaN
# 6773  1.3.6.1.4.1.9590.100.1.2.791687062125620465047...                NaN
# 6774  1.3.6.1.4.1.9590.100.1.2.125719193110475775290...                NaN
#
#       Study Date     Series Description  Manufacturer Modality  \
# 0     08-29-2017        ROI mask images           NaN       MG
# 1     08-29-2017        ROI mask images           NaN       MG
# 2     08-29-2017  full mammogram images           NaN       MG
# 3     08-29-2017  full mammogram images           NaN       MG
# 4     08-29-2017        ROI mask images           NaN       MG
# ...          ...                    ...           ...      ...
# 6770  07-20-2016         cropped images           NaN       MG
# 6771  07-21-2016        ROI mask images           NaN       MG
# 6772  07-20-2016  full mammogram images           NaN       MG
# 6773  07-20-2016  full mammogram images           NaN       MG
# 6774  07-21-2016        ROI mask images           NaN       MG
#
#                        SOP Class Name              SOP Class UID  \
# 0     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 1     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 2     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 3     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 4     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# ...                               ...                        ...
# 6770  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6771  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6772  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6773  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6774  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
#
#       Number of Images  Unnamed: 14 File Size  \
# 0                    2           14     06 MB
# 1                    2           14     62 MB
# 2                    1           27     84 MB
# 3                    1           28     97 MB
# 4                    2           13     41 MB
# ...                ...          ...       ...
# 6770                 1          379     24 KB
# 6771                 1           14     14 MB
# 6772                 1           37     35 MB
# 6773                 1           36     04 MB
# 6774                 2           21     47 MB
#
#                                           File Location  \
# 0     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_CC_1\08-29-...
# 1     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_MLO_1\08-29...
# 2     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_CC\08-29-20...
# 3     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_MLO\08-29-2...
# 4     .\CBIS-DDSM\Calc-Test_P_00038_RIGHT_CC_1\08-29...
# ...                                                 ...
# 6770  .\CBIS-DDSM\Mass-Training_P_02092_LEFT_MLO_1\0...
# 6771  .\CBIS-DDSM\Mass-Training_P_02092_LEFT_MLO_1\0...
# 6772  .\CBIS-DDSM\Mass-Training_P_02092_LEFT_MLO\07-...
# 6773  .\CBIS-DDSM\Mass-Training_P_02079_RIGHT_MLO\07...
# 6774  .\CBIS-DDSM\Mass-Training_P_01761_LEFT_MLO_1\0...
#
#            Download Timestamp
# 0     2022-02-28T21:13:14.487
# 1     2022-02-28T21:13:28.105
# 2     2022-02-28T21:13:35.311
# 3     2022-02-28T21:13:36.483
# 4     2022-02-28T21:13:46.913
# ...                       ...
# 6770   2022-03-01T21:24:32.04
# 6771  2022-03-01T21:24:42.228
# 6772   2022-03-01T21:25:04.66
# 6773  2022-03-01T21:25:15.016
# 6774  2022-03-01T21:56:42.561
#
# [6775 rows x 18 columns]

# %%
meta
# Out:
#                                              Series UID Collection  \
# 0     1.3.6.1.4.1.9590.100.1.2.419081637812053404913...  CBIS-DDSM
# 1     1.3.6.1.4.1.9590.100.1.2.188613955710170417803...  CBIS-DDSM
# 2     1.3.6.1.4.1.9590.100.1.2.374115997511889073021...  CBIS-DDSM
# 3     1.3.6.1.4.1.9590.100.1.2.174390361112646747718...  CBIS-DDSM
# 4     1.3.6.1.4.1.9590.100.1.2.244876997513875090239...  CBIS-DDSM
# ...                                                 ...        ...
# 6770  1.3.6.1.4.1.9590.100.1.2.321062807811123845106...  CBIS-DDSM
# 6771  1.3.6.1.4.1.9590.100.1.2.203989029910964209440...  CBIS-DDSM
# 6772  1.3.6.1.4.1.9590.100.1.2.290251769212905477734...  CBIS-DDSM
# 6773  1.3.6.1.4.1.9590.100.1.2.412558050811722685411...  CBIS-DDSM
# 6774  1.3.6.1.4.1.9590.100.1.2.364927700011315459741...  CBIS-DDSM
#
#       3rd Party Analysis                           Data Description URI  \
# 0                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 1                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 2                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 3                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 4                    NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# ...                  ...                                            ...
# 6770                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6771                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6772                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6773                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 6774                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
#
#                             Subject ID  \
# 0          Calc-Test_P_00038_LEFT_CC_1
# 1         Calc-Test_P_00038_LEFT_MLO_1
# 2            Calc-Test_P_00038_LEFT_CC
# 3           Calc-Test_P_00038_LEFT_MLO
# 4         Calc-Test_P_00038_RIGHT_CC_1
# ...                                ...
# 6770  Mass-Training_P_02092_LEFT_MLO_1
# 6771  Mass-Training_P_02092_LEFT_MLO_1
# 6772    Mass-Training_P_02092_LEFT_MLO
# 6773   Mass-Training_P_02079_RIGHT_MLO
# 6774  Mass-Training_P_01761_LEFT_MLO_1
#
#                                               Study UID  Study Description  \
# 0     1.3.6.1.4.1.9590.100.1.2.161465562211359959230...                NaN
# 1     1.3.6.1.4.1.9590.100.1.2.291121996131431385353...                NaN
# 2     1.3.6.1.4.1.9590.100.1.2.859354343102033567126...                NaN
# 3     1.3.6.1.4.1.9590.100.1.2.384159464510350889125...                NaN
# 4     1.3.6.1.4.1.9590.100.1.2.200764632211227648028...                NaN
# ...                                                 ...                ...
# 6770  1.3.6.1.4.1.9590.100.1.2.195655760513031195523...                NaN
# 6771  1.3.6.1.4.1.9590.100.1.2.222512969612930058132...                NaN
# 6772  1.3.6.1.4.1.9590.100.1.2.322851018411213611731...                NaN
# 6773  1.3.6.1.4.1.9590.100.1.2.791687062125620465047...                NaN
# 6774  1.3.6.1.4.1.9590.100.1.2.125719193110475775290...                NaN
#
#       Study Date     Series Description  Manufacturer Modality  \
# 0     08-29-2017        ROI mask images           NaN       MG
# 1     08-29-2017        ROI mask images           NaN       MG
# 2     08-29-2017  full mammogram images           NaN       MG
# 3     08-29-2017  full mammogram images           NaN       MG
# 4     08-29-2017        ROI mask images           NaN       MG
# ...          ...                    ...           ...      ...
# 6770  07-20-2016         cropped images           NaN       MG
# 6771  07-21-2016        ROI mask images           NaN       MG
# 6772  07-20-2016  full mammogram images           NaN       MG
# 6773  07-20-2016  full mammogram images           NaN       MG
# 6774  07-21-2016        ROI mask images           NaN       MG
#
#                        SOP Class Name              SOP Class UID  \
# 0     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 1     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 2     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 3     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 4     Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# ...                               ...                        ...
# 6770  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6771  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6772  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6773  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 6774  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
#
#       Number of Images  Unnamed: 14 File Size  \
# 0                    2           14     06 MB
# 1                    2           14     62 MB
# 2                    1           27     84 MB
# 3                    1           28     97 MB
# 4                    2           13     41 MB
# ...                ...          ...       ...
# 6770                 1          379     24 KB
# 6771                 1           14     14 MB
# 6772                 1           37     35 MB
# 6773                 1           36     04 MB
# 6774                 2           21     47 MB
#
#                                           File Location  \
# 0     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_CC_1\08-29-...
# 1     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_MLO_1\08-29...
# 2     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_CC\08-29-20...
# 3     .\CBIS-DDSM\Calc-Test_P_00038_LEFT_MLO\08-29-2...
# 4     .\CBIS-DDSM\Calc-Test_P_00038_RIGHT_CC_1\08-29...
# ...                                                 ...
# 6770  .\CBIS-DDSM\Mass-Training_P_02092_LEFT_MLO_1\0...
# 6771  .\CBIS-DDSM\Mass-Training_P_02092_LEFT_MLO_1\0...
# 6772  .\CBIS-DDSM\Mass-Training_P_02092_LEFT_MLO\07-...
# 6773  .\CBIS-DDSM\Mass-Training_P_02079_RIGHT_MLO\07...
# 6774  .\CBIS-DDSM\Mass-Training_P_01761_LEFT_MLO_1\0...
#
#            Download Timestamp
# 0     2022-02-28T21:13:14.487
# 1     2022-02-28T21:13:28.105
# 2     2022-02-28T21:13:35.311
# 3     2022-02-28T21:13:36.483
# 4     2022-02-28T21:13:46.913
# ...                       ...
# 6770   2022-03-01T21:24:32.04
# 6771  2022-03-01T21:24:42.228
# 6772   2022-03-01T21:25:04.66
# 6773  2022-03-01T21:25:15.016
# 6774  2022-03-01T21:56:42.561
#
# [6775 rows x 18 columns]
