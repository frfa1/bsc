# %%
import sys
import os

# Inserting siebling folder to sys. Ensures other code can be ran
# Note: Must have breast_cancer_classifier folder in the parent of the current folder
sys.path.insert(1, os.path.abspath("../breast_cancer_classifier"))

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
# %matplotlib inline

import numpy as np

from src.modeling.run_model_single import (
    load_model, load_inputs, process_augment_inputs, batch_to_tensor
)
import src.utilities.pickling as pickling
# Out:
# In /home/frfa/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/frfa/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/frfa/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
import pandas as pd

# %%
shared_parameters = {
    "device_type": "cpu", #gpu
    "gpu_number": 0,
    "max_crop_noise": (100, 100),
    "max_crop_size_noise": 100,
    "batch_size": 1,
    "seed": 0,
    "augmentation": True,
    "use_hdf5": True,
}

# %% [markdown]
# # Loading DDSM meta data
#
# Including png_file locations

# %%
basepath = "../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142"
meta_df = pd.read_csv(
    basepath + "/metadata2.csv"
)

# %%
 # Subsetting only full mammograms
meta_df = meta_df[meta_df["Series Description"] == "full mammogram images"]

# %%
# Subsetting standardized test cases
calc_test_df = meta_df[meta_df["Subject ID"].str.contains("Calc-Test")]
mass_test_df = meta_df[meta_df["Subject ID"].str.contains("Mass-Test")]

print(
    len(calc_test_df),
    len(mass_test_df)
)
# Out:
# 284 361

# %% [markdown]
# # Converting DICOMs to PNGs
#
# Using own function all_inbreast_to_png

# %%
from dicom_to_png16 import all_ddsm_to_png

# %%
calc_test_df = all_ddsm_to_png(calc_test_df, basepath)
# Out:
# Directory  png_versions  already exists
# /home/frfa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /home/frfa/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Directory  png_versions  already exists
# Directory  png_versions  already exists
# Directory  png_versions  already exists
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 10
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 20
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 30
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 40
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 50
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 60
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 70
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 80
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 90
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 100
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 110
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 120
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 130
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 140
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 150
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 160
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 170
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 180
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 190
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 200
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 210
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 220
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 230
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 240
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 250
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 260
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 270
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# 280
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created
# Directory  png_versions  Created

# %%
calc_test_df
# Out:
#                                             Series UID Collection  \
# 2    1.3.6.1.4.1.9590.100.1.2.374115997511889073021...  CBIS-DDSM
# 3    1.3.6.1.4.1.9590.100.1.2.174390361112646747718...  CBIS-DDSM
# 5    1.3.6.1.4.1.9590.100.1.2.263861248711313923336...  CBIS-DDSM
# 9    1.3.6.1.4.1.9590.100.1.2.442624602111129305133...  CBIS-DDSM
# 11   1.3.6.1.4.1.9590.100.1.2.272917492411709393015...  CBIS-DDSM
# ..                                                 ...        ...
# 601  1.3.6.1.4.1.9590.100.1.2.242128209412592948513...  CBIS-DDSM
# 603  1.3.6.1.4.1.9590.100.1.2.277098686410919869923...  CBIS-DDSM
# 604  1.3.6.1.4.1.9590.100.1.2.258951180113994815379...  CBIS-DDSM
# 605  1.3.6.1.4.1.9590.100.1.2.232308535910657861814...  CBIS-DDSM
# 610  1.3.6.1.4.1.9590.100.1.2.220517698812723136111...  CBIS-DDSM
#
#      3rd Party Analysis                           Data Description URI  \
# 2                   NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 3                   NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 5                   NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 9                   NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 11                  NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# ..                  ...                                            ...
# 601                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 603                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 604                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 605                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
# 610                 NaN  https://doi.org/10.7937/K9/TCIA.2016.7O02S9CY
#
#                       Subject ID  \
# 2      Calc-Test_P_00038_LEFT_CC
# 3     Calc-Test_P_00038_LEFT_MLO
# 5     Calc-Test_P_00038_RIGHT_CC
# 9    Calc-Test_P_00038_RIGHT_MLO
# 11     Calc-Test_P_00041_LEFT_CC
# ..                           ...
# 601  Calc-Test_P_02464_RIGHT_MLO
# 603   Calc-Test_P_02498_RIGHT_CC
# 604  Calc-Test_P_02498_RIGHT_MLO
# 605   Calc-Test_P_02501_RIGHT_CC
# 610  Calc-Test_P_02501_RIGHT_MLO
#
#                                              Study UID  Study Description  \
# 2    1.3.6.1.4.1.9590.100.1.2.859354343102033567126...                NaN
# 3    1.3.6.1.4.1.9590.100.1.2.384159464510350889125...                NaN
# 5    1.3.6.1.4.1.9590.100.1.2.177706148911820252341...                NaN
# 9    1.3.6.1.4.1.9590.100.1.2.328421320411501709324...                NaN
# 11   1.3.6.1.4.1.9590.100.1.2.696920639136398753090...                NaN
# ..                                                 ...                ...
# 601  1.3.6.1.4.1.9590.100.1.2.132696601911685338902...                NaN
# 603  1.3.6.1.4.1.9590.100.1.2.417835510412813100540...                NaN
# 604  1.3.6.1.4.1.9590.100.1.2.234958198411349241611...                NaN
# 605  1.3.6.1.4.1.9590.100.1.2.328020289613106819513...                NaN
# 610  1.3.6.1.4.1.9590.100.1.2.353727029012871868507...                NaN
#
#      Study Date     Series Description  Manufacturer  ...  \
# 2    08-29-2017  full mammogram images           NaN  ...
# 3    08-29-2017  full mammogram images           NaN  ...
# 5    08-29-2017  full mammogram images           NaN  ...
# 9    08-29-2017  full mammogram images           NaN  ...
# 11   08-29-2017  full mammogram images           NaN  ...
# ..          ...                    ...           ...  ...
# 601  08-29-2017  full mammogram images           NaN  ...
# 603  08-29-2017  full mammogram images           NaN  ...
# 604  08-29-2017  full mammogram images           NaN  ...
# 605  08-29-2017  full mammogram images           NaN  ...
# 610  08-29-2017  full mammogram images           NaN  ...
#
#                       SOP Class Name              SOP Class UID  \
# 2    Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 3    Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 5    Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 9    Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 11   Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# ..                               ...                        ...
# 601  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 603  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 604  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 605  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
# 610  Secondary Capture Image Storage  1.2.840.10008.5.1.4.1.1.7
#
#     Number of Images  Unnamed: 14  File Size  \
# 2                  1           27      84 MB
# 3                  1           28      97 MB
# 5                  1           25      73 MB
# 9                  1           27      64 MB
# 11                 1           45      13 MB
# ..               ...          ...        ...
# 601                1           67      95 MB
# 603                1           25      33 MB
# 604                1           30      03 MB
# 605                1           21      84 MB
# 610                1           24      90 MB
#
#                                          File Location  \
# 2    .\CBIS-DDSM\Calc-Test_P_00038_LEFT_CC\08-29-20...
# 3    .\CBIS-DDSM\Calc-Test_P_00038_LEFT_MLO\08-29-2...
# 5    .\CBIS-DDSM\Calc-Test_P_00038_RIGHT_CC\08-29-2...
# 9    .\CBIS-DDSM\Calc-Test_P_00038_RIGHT_MLO\08-29-...
# 11   .\CBIS-DDSM\Calc-Test_P_00041_LEFT_CC\08-29-20...
# ..                                                 ...
# 601  .\CBIS-DDSM\Calc-Test_P_02464_RIGHT_MLO\08-29-...
# 603  .\CBIS-DDSM\Calc-Test_P_02498_RIGHT_CC\08-29-2...
# 604  .\CBIS-DDSM\Calc-Test_P_02498_RIGHT_MLO\08-29-...
# 605  .\CBIS-DDSM\Calc-Test_P_02501_RIGHT_CC\08-29-2...
# 610  .\CBIS-DDSM\Calc-Test_P_02501_RIGHT_MLO\08-29-...
#
#           Download Timestamp  \
# 2    2022-02-28T21:13:35.311
# 3    2022-02-28T21:13:36.483
# 5    2022-02-28T21:13:50.957
# 9    2022-02-28T21:14:25.869
# 11   2022-02-28T21:15:00.196
# ..                       ...
# 601  2022-03-01T07:52:56.287
# 603  2022-03-01T07:53:09.434
# 604  2022-03-01T07:53:16.028
# 605  2022-03-01T07:53:20.984
# 610  2022-03-01T07:53:42.906
#
#                                               png_path png_filename  \
# 2    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 3    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 5    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 9    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 11   ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# ..                                                 ...          ...
# 601  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 603  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 604  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 605  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
# 610  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...      1-1.png
#
#                                               png_base
# 2    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 3    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 5    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 9    ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 11   ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# ..                                                 ...
# 601  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 603  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 604  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 605  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
# 610  ../data/cbis-ddsm/manifest-ZkhPvrLo52167308727...
#
# [284 rows x 21 columns]

# %% [markdown]
# # Cropping images
#
# This is done to reduce the size of the images before inputting to models.

# %%
# Github library
import src.cropping.crop_single as crop_single
import pathlib

import os.path
from os import path

# %%
count = 0
for row in calc_test_df.itertuples():
    count += 1
    if count % 10 == 0:
        print(count)    
        
    if path.exists(str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename))) \
    and path.exists(str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename.replace(".png", ".pkl")))):
        print("Cropped image already exist. Skipping. Count: ", count)
        continue

    subject_id = row._5.split("_")
    
    crop_single.crop_single_mammogram(
        str(pathlib.PurePosixPath(row.png_path)),
        "NO",
        subject_id[-2][0] + "-" + subject_id[-1], #row.Laterality + "-" + row.View,
        str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename)),
        str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename.replace(".png", ".pkl"))),
        1,
        50,
    )
# Out:
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00038_LEFT_CC/08-29-2017-DDSM-NA-96009/1.000000-full mammogram images-63992/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  1
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00038_LEFT_MLO/08-29-2017-DDSM-NA-17613/1.000000-full mammogram images-97934/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  2
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00038_RIGHT_CC/08-29-2017-DDSM-NA-28468/1.000000-full mammogram images-63304/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  3
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00038_RIGHT_MLO/08-29-2017-DDSM-NA-85215/1.000000-full mammogram images-08846/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  4
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00041_LEFT_CC/08-29-2017-DDSM-NA-52275/1.000000-full mammogram images-92812/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  5
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00041_LEFT_MLO/08-29-2017-DDSM-NA-80130/1.000000-full mammogram images-81387/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  6
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00077_LEFT_CC/08-29-2017-DDSM-NA-74428/1.000000-full mammogram images-40544/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  7
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00077_LEFT_MLO/08-29-2017-DDSM-NA-02297/1.000000-full mammogram images-61951/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  8
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00077_RIGHT_CC/08-29-2017-DDSM-NA-38195/1.000000-full mammogram images-87486/png_versions/cropped/1-1.png
# Cropped image already exist. Skipping. Count:  9
# 10
# ../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00077_RIGHT_MLO/08-29-2017-DDSM-NA-29026/1.000000-full mammogram images-34212/png_versions/cropped/1-1.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-46f38681ce22> in <module>
#      21         str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename.replace(".png", ".pkl"))),
#      22         1,
# ---> 23         50,
#      24     )
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/cropping/crop_single.py in crop_single_mammogram(mammogram_path, horizontal_flip, view, cropped_mammogram_path, metadata_path, num_iterations, buffer_size)
#      46         output_file_path=cropped_mammogram_path,
#      47         num_iterations=num_iterations,
# ---> 48         buffer_size=buffer_size,
#      49     )
#      50     metadata_dict["window_location"] = cropped_image_info[0]
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/cropping/crop_mammogram.py in crop_mammogram_one_image(scan, input_file_path, output_file_path, num_iterations, buffer_size)
#     310             num_iterations,
#     311             buffer_size,
# --> 312             1/3
#     313         )
#     314     except Exception as error:
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/cropping/crop_mammogram.py in crop_img_from_largest_connected(img, mode, erode_dialate, iterations, buffer_size, find_rightmost_from_ratio)
#     184
#     185     # Select mask for largest connected component
# --> 186     largest_mask = get_mask_of_largest_connected_component(img_mask)
#     187
#     188     # Dilation to recover the original mask, excluding the thin lines
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/cropping/crop_mammogram.py in get_mask_of_largest_connected_component(img_mask)
#      56     Finds the largest connected component from the mask of the image
#      57     """
# ---> 58     mask, mask_pixels_dict = get_masks_and_sizes_of_connected_components(img_mask)
#      59     largest_mask_index = pd.Series(mask_pixels_dict).idxmax()
#      60     largest_mask = mask == largest_mask_index
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/cropping/crop_mammogram.py in get_masks_and_sizes_of_connected_components(img_mask)
#      47         if img_mask[this_mask][0] != 0:
#      48             # Exclude the 0-valued mask
# ---> 49             mask_pixels_dict[i] = np.sum(this_mask)
#      50
#      51     return mask, mask_pixels_dict
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2246
#    2247     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2248                           initial=initial, where=where)
#    2249
#    2250
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %% [markdown]
# # Get optimal centers

# %%
# Github library
import src.optimal_centers.get_optimal_center_single as center_single

# %%
for row in calc_test_df.itertuples():
    if row.Index % 10 == 0:
        print("Done with row " + str(row.Index))
        
    center_single.get_optimal_center_single(
        str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename)), # cropped_mammogram_path,
        str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename.replace(".png", ".pkl"))) # metadata_path
    )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-fb82b5a265d8> in <module>
#       7         str(pathlib.PurePosixPath(row.png_path)), # non-cropped png
#       8         #str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename.replace(".png", ".pkl"))) # metadata_path
# ----> 9         str(pathlib.PurePosixPath(row.png_base / row.png_filename.replace(".png", ".pkl"))), # non-cropped plk
#      10     )
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/optimal_centers/get_optimal_center_single.py in get_optimal_center_single(cropped_mammogram_path, metadata_path)
#      35     Get optimal center for single example
#      36     """
# ---> 37     metadata = pickling.unpickle_from_file(metadata_path)
#      38     image = reading_images.read_image_png(cropped_mammogram_path)
#      39     optimal_center = get_optimal_centers.extract_center(metadata, image)
#
# /mnt/d/Studie/Bachelor/Bachelor Project/breast_cancer_classifier/src/utilities/pickling.py in unpickle_from_file(file_name)
#      33
#      34 def unpickle_from_file(file_name):
# ---> 35     with open(file_name, 'rb') as handle:
#      36         return pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142/CBIS-DDSM/Calc-Test_P_00038_LEFT_CC/08-29-2017-DDSM-NA-96009/1.000000-full mammogram images-63992/png_versions/1-1.pkl'

# %% [markdown]
# # Bulk Image-Only Model Predictions
#
# A dictionary containing the configuration parameters for image-only model, and load the corresponding weights.

# %%
def make_pred(shared_parameters, row, meta_df):
    subject_id = row._5.split("_")
    
    random_number_generator = np.random.RandomState(shared_parameters["seed"])

    image_only_parameters = shared_parameters.copy()
    image_only_parameters["view"] = subject_id[-2][0] + "-" + subject_id[-1]  # row.Laterality + "-" + row.View #"L-CC"
    image_only_parameters["use_heatmaps"] = False
    image_only_parameters["model_path"] = "../breast_cancer_classifier/models/ImageOnly__ModeImage_weights.p"
    model, device = load_model(image_only_parameters)
    
    model_input = load_inputs(
    image_path = str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename)), #"sample_single_output/cropped.png",
    metadata_path = str(pathlib.PurePosixPath(row.png_base / "cropped" / row.png_filename.replace(".png", ".pkl"))),  #"sample_single_output/cropped_metadata.pkl",
    use_heatmaps=False,
    )
    
    batch = [
        process_augment_inputs(
            model_input=model_input,
            random_number_generator=random_number_generator,
            parameters=image_only_parameters,
        ),
    ]
    tensor_batch = batch_to_tensor(batch, device)
    
    y_hat = model(tensor_batch)
    
    predictions = np.exp(y_hat.cpu().detach().numpy())[:, :2, 1]
    predictions_dict = {
        "benign": float(predictions[0][0]),
        "malignant": float(predictions[0][1]),
    }
    
    # Assign probabilities to df location
    meta_df.loc[meta_df["png_path"] == row.png_path, "benign"] = float(predictions[0][0])
    meta_df.loc[meta_df["png_path"] == row.png_path, "malignant"] = float(predictions[0][1])
    
    return predictions_dict

# %%
calc_test_df["benign"] = 0
calc_test_df["malignant"] = 0

# %%
predictions = []
for row in calc_test_df.itertuples():
    print(row.Index)
        
    predictions.append(
        make_pred(shared_parameters, row, calc_test_df)
    )

# %% [markdown]
# # Joining with label data
#
# After predictions, join data with the label data

# %%
basepath = "../data/cbis-ddsm/manifest-ZkhPvrLo5216730872708713142"
calc_case_description_test_set = pd.read_csv(
    "../data/cbis-ddsm/calc_case_description_test_set.csv"
)

# %%
len(calc_case_description_test_set["image file path"].unique())

# %% [markdown]
# Removes cases with ambiguous labels, as those correspond to ROI-level labels (rather than whole image)

# %%
new_df = calc_case_description_test_set.groupby(["image file path"])["pathology"].nunique().reset_index(name='count') \
                             .sort_values(['count'], ascending=False)
multi_pathology = list(new_df[new_df["count"] > 1]["image file path"])

calc2 = calc_case_description_test_set[~calc_case_description_test_set["image file path"].isin(multi_pathology)]

# %%
calc2["Subject ID"] = calc2["image file path"].str.split("/").str[0]

# %% [markdown]
# Merge the datasets

# %%
new_df = calc_test_df.merge(calc2, on="Subject ID")

# %%
new_df.columns

# %%
new_df.drop_duplicates(subset=["Subject ID"], inplace=True)

# %%
new_df["pathology"].unique()

# %% [markdown]
# # Making ROC curve
#
# Used for AUC.

# %%
new_df["pred_y"] = "benign"
new_df.loc[new_df["benign"] < new_df["malignant"], "pred_y"] = "malignant"

new_df["true_y"] = "benign"
new_df.loc[(new_df["pathology"] == "MALIGNANT"), "true_y"] = "malignant"

# %%
new_df

# %%
from sklearn import metrics

# %%
# ROC malignant / not-malignant
y = np.array(
    new_df["true_y"]
)
y = np.where(y != "malignant", 0, y)
y = np.where(y == "malignant", 1, y)
y = np.int_(y)

pred_y = np.array(
    new_df["malignant"]
)

# %%
# ROC benign / not-benign
y2 = np.array(
    new_df["true_y"]
)
y2 = np.where(y2 != "benign", 0, y2)
y2 = np.where(y2 == "benign", 1, y2)
y2 = np.int_(y2)

pred_y2 = np.array(
    new_df["benign"]
)

# %%
print(y, pred_y)
print(y2, pred_y2)

# %%
# malignant
fpr, tpr, thresholds = metrics.roc_curve(y, pred_y, pos_label=1)
roc_auc = metrics.auc(fpr, tpr)

# benign
fpr2, tpr2, thresholds2 = metrics.roc_curve(y2, pred_y2, pos_label=1)
roc_auc2 = metrics.auc(fpr2, tpr2)

# %%
print(fpr, tpr)
print(fpr2, tpr2)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Malignant")
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure()
lw = 2
plt.plot(
    fpr2,
    tpr2,
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.2f)" % roc_auc2,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Benign")
plt.legend(loc="lower right")
plt.show()
